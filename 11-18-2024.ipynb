# %% [markdown]
# <h2>The first metric we analyzed regarded police arrests.</h2>

# %% [markdown]
# "With the data provided, we see that Central Business District is a no go. They have the most amount of crime in record. However, Mt. Oliver Neighborhood might have the lowest, but their population is at a low of 3,394. If we compare that to Squirrel Hill South, their population is over 14,500."

# %% [markdown]
# ![alt](data:image/png;base64,...)

# %% [markdown]
# <h2>The next metric we analyzed regarded tax delinquency</h2>

# %% [markdown]
# "Lincoln-Lemington-Belmar, Mount Oliver, Spring Hill–City View, Point Breeze North, Chatham Village, Hilltop, Brunot Island, Four Mile Run, North Point Breeze, Squirrel Hill South, The Valley, Station Square, Saint Clair, Lincoln–Lemington–Belmar, Cultural District, Chartiers, St. Clair, Panther Hollow, Duck Hollow, Chartiers City, SouthSide Works, Summerset, Mexican War Streets, Washington's Landing, Crawford Roberts, Park Place, Mount Oliver Borough, Spring Hill-City View, Mt. Oliver, Squirrel Hill North"<br>
# <b>These are the neighborhoods which had no recorded instances of tax delinquency in 2017.</b>

# %% [markdown]
# <h2>The last metric we studied regarded COVID-19 vaccinations</h2>

# %% [markdown]
# "The city with the highest record of vaccinations is Squirrel Hill South, with a number of 5347 vaccinations! Thats ~58 times more than the average!"

# %% [markdown]
# <h1>Conclusion</h1>

# %% [markdown]
# The conclusion we came to from this data is that Squirrel Hill South is the best neighborhood within Pittsburgh. It has the highest vaccination rate in the city, it didn't have any instances of tax delinquency, and it represented a relatively average percentage of police arrests (at ~1.3%) with a relatively large population.
